# %% [markdown]
# # Student Alcohol Consumption

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the datasets *student-mat* and *student-por* and merge them.

# %%
student_mat=pd.read_csv("C:/Users/user/Desktop/Gurgaon course/Python_homeworks/Pandas Exercises/Pandas Exercises/Exercise Data Files/Pandas Exercise Lambda Functions Files/student-mat.csv",sep=",")
student_por=pd.read_csv("C:/Users/user/Desktop/Gurgaon course/Python_homeworks/Pandas Exercises/Pandas Exercises/Exercise Data Files/Pandas Exercise Lambda Functions Files/student-por.csv",sep=",")
df=pd.concat([student_mat,student_por])
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %% [markdown]
# ### Step 3. Assign it to a variable called df.

# %% [markdown]
# ### Step 4. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
df=df.loc[:, 'school':'guardian']
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %% [markdown]
# ### Step 5. Create a lambda function that captalize strings.

# %%
df.applymap(lambda s:s.upper() if type(s) == str else s)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   AT_HOME   TEACHER
# 1       GP   F   17       U     GT3       T     1     1   AT_HOME     OTHER
# 2       GP   F   15       U     LE3       T     1     1   AT_HOME     OTHER
# 3       GP   F   15       U     GT3       T     4     2    HEALTH  SERVICES
# 4       GP   F   16       U     GT3       T     3     3     OTHER     OTHER
# 5       GP   M   16       U     LE3       T     4     3  SERVICES     OTHER
# 6       GP   M   16       U     LE3       T     2     2     OTHER     OTHER
# 7       GP   F   17       U     GT3       A     4     4     OTHER   TEACHER
# 8       GP   M   15       U     LE3       A     3     2  SERVICES     OTHER
# 9       GP   M   15       U     GT3       T     3     4     OTHER     OTHER
# 10      GP   F   15       U     GT3       T     4     4   TEACHER    HEALTH
# ...

# %% [markdown]
# ### Step 6. Capitalize both Mjob and Fjob

# %%
df.loc[:,'Mjob':'Fjob'].apply(lambda x: x.str.upper())
# Out:
#          Mjob      Fjob
# 0     AT_HOME   TEACHER
# 1     AT_HOME     OTHER
# 2     AT_HOME     OTHER
# 3      HEALTH  SERVICES
# 4       OTHER     OTHER
# 5    SERVICES     OTHER
# 6       OTHER     OTHER
# 7       OTHER   TEACHER
# 8    SERVICES     OTHER
# 9       OTHER     OTHER
# 10    TEACHER    HEALTH
# 11   SERVICES     OTHER
# 12     HEALTH  SERVICES
# 13    TEACHER     OTHER
# 14      OTHER     OTHER
# 15     HEALTH     OTHER
# 16   SERVICES  SERVICES
# 17      OTHER     OTHER
# 18   SERVICES  SERVICES
# 19     HEALTH     OTHER
# 20    TEACHER     OTHER
# 21     HEALTH    HEALTH
# 22    TEACHER     OTHER
# 23      OTHER     OTHER
# 24   SERVICES    HEALTH
# 25   SERVICES  SERVICES
# 26      OTHER     OTHER
# 27     HEALTH  SERVICES
# 28   SERVICES     OTHER
# 29    TEACHER   TEACHER
# ..        ...       ...
# 619  SERVICES  SERVICES
# 620   AT_HOME   AT_HOME
# 621     OTHER  SERVICES
# 622   AT_HOME     OTHER
# 623   TEACHER  SERVICES
# 624     OTHER  SERVICES
# ...

# %% [markdown]
# ### Step 7. Print the last elements of the data set.

# %%
last_elements=df.iloc[-1:]
last_elements
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob   Fjob  \
# 648     MS   M   18       R     LE3       T     3     2  services  other
#
#      reason guardian
# 648  course   mother

# %% [markdown]
# ### Step 8. Did you notice the original dataframe is still lowercase? Why is that? Fix it and captalize Mjob and Fjob.

# %%
df.loc[:,'Mjob':'Fjob'].apply(lambda x: x.str.upper())
# Out:
#          Mjob      Fjob
# 0     AT_HOME   TEACHER
# 1     AT_HOME     OTHER
# 2     AT_HOME     OTHER
# 3      HEALTH  SERVICES
# 4       OTHER     OTHER
# 5    SERVICES     OTHER
# 6       OTHER     OTHER
# 7       OTHER   TEACHER
# 8    SERVICES     OTHER
# 9       OTHER     OTHER
# 10    TEACHER    HEALTH
# 11   SERVICES     OTHER
# 12     HEALTH  SERVICES
# 13    TEACHER     OTHER
# 14      OTHER     OTHER
# 15     HEALTH     OTHER
# 16   SERVICES  SERVICES
# 17      OTHER     OTHER
# 18   SERVICES  SERVICES
# 19     HEALTH     OTHER
# 20    TEACHER     OTHER
# 21     HEALTH    HEALTH
# 22    TEACHER     OTHER
# 23      OTHER     OTHER
# 24   SERVICES    HEALTH
# 25   SERVICES  SERVICES
# 26      OTHER     OTHER
# 27     HEALTH  SERVICES
# 28   SERVICES     OTHER
# 29    TEACHER   TEACHER
# ..        ...       ...
# 619  SERVICES  SERVICES
# 620   AT_HOME   AT_HOME
# 621     OTHER  SERVICES
# 622   AT_HOME     OTHER
# 623   TEACHER  SERVICES
# 624     OTHER  SERVICES
# ...

# %% [markdown]
# ### Step 9. Create a function called majority that return a boolean value to a new column called legal_drinker

# %%
def majority(x):
    if x>=18:
        return 'True'
    else:
        return 'False'


df["legal_drinker"] = df["age"].apply(majority)
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %% [markdown]
# ### Step 10. Multiply every number of the dataset by 10.

# %%
df.select_dtypes(include=['int']) * 10
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...
