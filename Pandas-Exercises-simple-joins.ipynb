# %% [markdown]
# # MPG Cars

# %% [markdown]
# ### Introduction:
#
# The following exercise utilizes data from [UC Irvine Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Auto+MPG)
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the  datasets [cars1.csv](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/Merge/Auto_MPG/cars1.csv) and [cars2.csv](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/Merge/Auto_MPG/cars2.csv) from the folder

# %%
pd.read_csv("C:/Users/user/Desktop/Gurgaon course/Python_homeworks/Pandas Exercises/Pandas Exercises/Exercise Data Files/Pandas Exercise Simple Joins files/cars1.csv")
pd.read_csv("C:/Users/user/Desktop/Gurgaon course/Python_homeworks/Pandas Exercises/Pandas Exercises/Exercise Data Files/Pandas Exercise Simple Joins files/cars2.csv")
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    33.0          4            91         53    1795          17.4     76
# 1    20.0          6           225        100    3651          17.7     76
# 2    18.0          6           250         78    3574          21.0     76
# 3    18.5          6           250        110    3645          16.2     76
# 4    17.5          6           258         95    3193          17.8     76
# 5    29.5          4            97         71    1825          12.2     76
# 6    32.0          4            85         70    1990          17.0     76
# 7    28.0          4            97         75    2155          16.4     76
# 8    26.5          4           140         72    2565          13.6     76
# 9    20.0          4           130        102    3150          15.7     76
# 10   13.0          8           318        150    3940          13.2     76
# ...

# %% [markdown]
#    ### Step 3. Assign each to a to a variable called cars1 and cars2

# %%
cars1=pd.read_csv("C:/Users/user/Desktop/Gurgaon course/Python_homeworks/Pandas Exercises/Pandas Exercises/Exercise Data Files/Pandas Exercise Simple Joins files/cars1.csv")
cars2=pd.read_csv("C:/Users/user/Desktop/Gurgaon course/Python_homeworks/Pandas Exercises/Pandas Exercises/Exercise Data Files/Pandas Exercise Simple Joins files/cars2.csv")
cars1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# 5    15.0          8           429        198    4341          10.0     70
# 6    14.0          8           454        220    4354           9.0     70
# 7    14.0          8           440        215    4312           8.5     70
# 8    14.0          8           455        225    4425          10.0     70
# 9    15.0          8           390        190    3850           8.5     70
# 10   15.0          8           383        170    3563          10.0     70
# ...

# %% [markdown]
# ### Step 4. It seems our first dataset has some unnamed blank columns, fix cars1

# %%
cars1=cars1.dropna(axis=1)
cars1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# 5    15.0          8           429        198    4341          10.0     70
# 6    14.0          8           454        220    4354           9.0     70
# 7    14.0          8           440        215    4312           8.5     70
# 8    14.0          8           455        225    4425          10.0     70
# 9    15.0          8           390        190    3850           8.5     70
# 10   15.0          8           383        170    3563          10.0     70
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in each dataset?

# %%
x=cars1.count(axis=0)
y=cars2.count(axis=0)
print(x)
print(y)
# Out:
# mpg             198
# cylinders       198
# displacement    198
# horsepower      198
# weight          198
# acceleration    198
# model           198
# origin          198
# car             198
# dtype: int64
# mpg             200
# cylinders       200
# displacement    200
# horsepower      200
# weight          200
# acceleration    200
# model           200
# origin          200
# car             200
# dtype: int64

# %% [markdown]
# ### Step 6. Join cars1 and cars2 into a single DataFrame called cars

# %%
cars=pd.concat([cars1,cars2])
cars
cars.shape[0]
# Out:
# 398

# %% [markdown]
# ### Step 7. There is a column missing, called owners. Create a random number Series from 15,000 to 73,000.

# %%
owners=pd.Series(np.random.randint(15000,73000,398))
owners
# Out:
# 0      28163
# 1      29688
# 2      21233
# 3      21146
# 4      65997
# 5      22347
# 6      54489
# 7      37079
# 8      36513
# 9      31512
# 10     38007
# 11     51176
# 12     20766
# 13     69234
# 14     68243
# 15     19056
# 16     63740
# 17     35318
# 18     57747
# 19     68527
# 20     57199
# 21     24142
# 22     55726
# 23     36491
# 24     58834
# 25     29922
# 26     49877
# 27     19134
# 28     55558
# 29     47647
#        ...
# 368    24317
# 369    31773
# 370    22099
# 371    43464
# 372    71190
# 373    30621
# 374    45150
# 375    57302
# 376    52735
# 377    61832
# 378    41304
# 379    46684
# 380    30437
# 381    59265
# 382    40584
# 383    29475
# 384    26703
# 385    69460
# 386    44536
# 387    52194
# 388    45536
# 389    46155
# 390    44160
# 391    43570
# 392    33017
# 393    64267
# 394    15535
# 395    68610
# 396    51771
# 397    61236
# Length: 398, dtype: int32

# %% [markdown]
# ### Step 8. Add the column owners to cars

# %%
cars["owners"]=owners

# %%
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# 5    15.0          8           429        198    4341          10.0     70
# 6    14.0          8           454        220    4354           9.0     70
# 7    14.0          8           440        215    4312           8.5     70
# 8    14.0          8           455        225    4425          10.0     70
# 9    15.0          8           390        190    3850           8.5     70
# 10   15.0          8           383        170    3563          10.0     70
# ...
